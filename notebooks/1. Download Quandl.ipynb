# %%
import os, sys
sys.path.insert(0, os.path.dirname(os.getcwd()))

# %%
import requests
import copy
import pandas as pd
import numpy as np

from ml_trader.utils import load_config

# %%
config = load_config()
TICKERS = config["tickers"]

# %%
filepath = "/Users/kirillgugaev/Dev/finance/ML-shares-trader/datasets/quandl/SHARADAR_TICKERS_6cc728d11002ab9cb99aa8654a6b9f4e.csv"

# %% [markdown]
# ## Tickers from Quandl (exists on Tinkoff & on Quandl)

# %%
tickers_df = pd.read_csv(filepath)
tickers_df[tickers_df['table'] == 'SF1']
tickers_df
# Out:
#       table  permaticker ticker                                  name  \
# 0       SF1       196290      A              Agilent Technologies Inc
# 1       SF1       124392     AA                            Alcoa Corp
# 2       SF1       122827   AAAB                 Admiralty Bancorp Inc
# 3       SF1       120538  AAAGY             Altana Aktiengesellschaft
# 4       SF1       155760   AAAP  Advanced Accelerator Applications SA
# ...     ...          ...    ...                                   ...
# 49022  SF3B       635775    NaN               LONG WALK MANAGEMENT LP
# 49023  SF3B       635630    NaN  CARDINAL POINT WEALTH MANAGEMENT LLC
# 49024  SF3B       635623    NaN                          CORSICANA CO
# 49025  SF3B       635648    NaN                 BANK OF NEW HAMPSHIRE
# 49026  SF3B       635783    NaN    SAGEWORTH TRUST CO OF SOUTH DAKOTA
#
#       exchange isdelisted               category     cusips  siccode  \
# 0         NYSE          N  Domestic Common Stock  00846U101   3826.0
# 1         NYSE          N  Domestic Common Stock  013872106   3334.0
# 2       NASDAQ          Y  Domestic Common Stock  007231103   6022.0
# 3         NYSE          Y       ADR Common Stock  02143N103   2834.0
# 4       NASDAQ          Y       ADR Common Stock  00790T100   2834.0
# ...        ...        ...                    ...        ...      ...
# 49022      NaN        NaN                    NaN        NaN      NaN
# 49023      NaN        NaN                    NaN        NaN      NaN
# 49024      NaN        NaN                    NaN        NaN      NaN
# 49025      NaN        NaN                    NaN        NaN      NaN
# 49026      NaN        NaN                    NaN        NaN      NaN
#
#                                sicsector  ... currency             location  \
# 0                          Manufacturing  ...      USD    California; U.S.A
# 1                          Manufacturing  ...      USD  Pennsylvania; U.S.A
# 2      Finance Insurance And Real Estate  ...      USD       Florida; U.S.A
# 3                          Manufacturing  ...      EUR               Jordan
# 4                          Manufacturing  ...      EUR               France
# ...                                  ...  ...      ...                  ...
# 49022                                NaN  ...      USD                  NaN
# 49023                                NaN  ...      USD                  NaN
# 49024                                NaN  ...      USD                  NaN
# 49025                                NaN  ...      USD                  NaN
# 49026                                NaN  ...      USD                  NaN
#
#       lastupdated  firstadded firstpricedate lastpricedate firstquarter  \
# 0      2021-06-01  2014-09-26     1999-11-18    2021-07-21   1997-06-30
# 1      2021-05-05  2016-11-01     2016-11-01    2021-07-21   2014-12-31
# 2      2019-07-29  2017-09-09     1998-09-25    2003-01-28   1997-09-30
# 3      2019-05-17  2018-02-13     2002-05-22    2010-08-12   2000-12-31
# 4      2020-10-08  2016-05-19     2015-11-11    2018-02-09   2012-12-31
# ...           ...         ...            ...           ...          ...
# 49022         NaN         NaN            NaN           NaN   2021-06-30
# 49023         NaN         NaN            NaN           NaN   2020-12-31
# 49024         NaN         NaN            NaN           NaN   2021-06-30
# 49025         NaN         NaN            NaN           NaN   2021-06-30
# 49026         NaN         NaN            NaN           NaN   2020-12-31
#
#       lastquarter                                         secfilings  \
# 0      2021-03-31  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 1      2021-03-31  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 2      2002-09-30  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 3      2005-12-31  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 4      2017-09-30  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# ...           ...                                                ...
# 49022  2021-06-30  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 49023  2021-03-31  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 49024  2021-06-30  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 49025  2021-06-30  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 49026  2021-03-31  https://www.sec.gov/cgi-bin/browse-edgar?actio...
#
#                   companysite
# 0      http://www.agilent.com
# 1        http://www.alcoa.com
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 49022                     NaN
# 49023                     NaN
# 49024                     NaN
# 49025                     NaN
# 49026                     NaN
#
# [49027 rows x 28 columns]

# %%
tmp = pd.DataFrame()
tmp['ticker'] = TICKERS
tmp['flag'] = True
tmp.head()
# Out:
#   ticker  flag
# 0     ZI  True
# 1   HALO  True
# 2    WGO  True
# 3   VIPS  True
# 4    OSK  True

# %%
tickers_df = pd.merge(tickers_df, tmp, on='ticker', how='left')
tickers_df['flag'] = tickers_df['flag'].fillna(False)
tickers_df = tickers_df[tickers_df['flag']]
del tickers_df['flag']

tickers_df.reset_index(drop=True)
# Out:
#      table  permaticker ticker                         name exchange  \
# 0      SF1       196290      A     Agilent Technologies Inc     NYSE
# 1      SF1       124392     AA                   Alcoa Corp     NYSE
# 2      SF1       199960    AAL  American Airlines Group Inc   NASDAQ
# 3      SF1       632687    AAN          Aaron's Company Inc     NYSE
# 4      SF1       198259   AAON                     Aaon Inc   NASDAQ
# ...    ...          ...    ...                          ...      ...
# 2979   SEP       194904   ZUMZ                   Zumiez Inc   NASDAQ
# 2980   SEP       119847    ZUO                    Zuora Inc     NYSE
# 2981   SEP       634860     ZY                 Zymergen Inc   NASDAQ
# 2982   SEP       157146   ZYNE  Zynerba Pharmaceuticals Inc   NASDAQ
# 2983   SEP       198130   ZYXI                    Zynex Inc   NASDAQ
#
#      isdelisted               category     cusips  siccode  \
# 0             N  Domestic Common Stock  00846U101   3826.0
# 1             N  Domestic Common Stock  013872106   3334.0
# 2             N  Domestic Common Stock  02376R102   4512.0
# 3             N  Domestic Common Stock  00258W108   7359.0
# 4             N  Domestic Common Stock  000360206   3585.0
# ...         ...                    ...        ...      ...
# 2979          N  Domestic Common Stock  989817101   5600.0
# 2980          N  Domestic Common Stock  98983V106   7372.0
# 2981          N  Domestic Common Stock  98985X100   8731.0
# 2982          N  Domestic Common Stock  98986X109   2834.0
# 2983          N  Domestic Common Stock  98986M103   3845.0
#
#                                               sicsector  ... currency  \
# 0                                         Manufacturing  ...      USD
# 1                                         Manufacturing  ...      USD
# 2     Transportation Communications Electric Gas And...  ...      USD
# 3                                              Services  ...      USD
# 4                                         Manufacturing  ...      USD
# ...                                                 ...  ...      ...
# 2979                                       Retail Trade  ...      USD
# 2980                                           Services  ...      USD
# 2981                                           Services  ...      USD
# 2982                                      Manufacturing  ...      USD
# 2983                                      Manufacturing  ...      USD
#
#                  location lastupdated  firstadded firstpricedate  \
# 0       California; U.S.A  2021-06-01  2014-09-26     1999-11-18
# 1     Pennsylvania; U.S.A  2021-05-05  2016-11-01     2016-11-01
# 2            Texas; U.S.A  2021-04-22  2015-04-14     2013-12-09
# 3          Georgia; U.S.A  2021-05-02  2020-12-02     2020-11-25
# 4         Oklahoma; U.S.A  2021-05-06  2014-10-14     1992-12-16
# ...                   ...         ...         ...            ...
# 2979    Washington; U.S.A  2021-07-21  2014-10-27     2005-05-06
# 2980    California; U.S.A  2021-07-21  2018-04-14     2018-04-12
# 2981    California; U.S.A  2021-07-21  2021-04-22     2021-04-22
# 2982  Pennsylvania; U.S.A  2021-07-21  2016-04-15     2015-08-05
# 2983      Colorado; U.S.A  2021-07-21  2016-02-17     2004-02-25
#
#      lastpricedate firstquarter lastquarter  \
# 0       2021-07-21   1997-06-30  2021-03-31
# 1       2021-07-21   2014-12-31  2021-03-31
# 2       2021-07-21   2012-12-31  2021-03-31
# 3       2021-07-21   2018-12-31  2021-03-31
# 4       2021-07-21   1996-12-31  2021-03-31
# ...            ...          ...         ...
# 2979    2021-07-21   2003-12-31  2021-03-31
# 2980    2021-07-21   2016-12-31  2021-03-31
# 2981    2021-07-21   2019-12-31  2021-03-31
# 2982    2021-07-21   2013-12-31  2021-03-31
# 2983    2021-07-21   2008-03-31  2021-03-31
#
#                                              secfilings  \
# 0     https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 1     https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 2     https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 3     https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 4     https://www.sec.gov/cgi-bin/browse-edgar?actio...
# ...                                                 ...
# 2979  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 2980  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 2981  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 2982  https://www.sec.gov/cgi-bin/browse-edgar?actio...
# 2983  https://www.sec.gov/cgi-bin/browse-edgar?actio...
#
#                   companysite
# 0      http://www.agilent.com
# 1        http://www.alcoa.com
# 2           http://www.aa.com
# 3                         NaN
# 4         http://www.aaon.com
# ...                       ...
# 2979    http://www.zumiez.com
# 2980     http://www.zuora.com
# 2981  http://www.zymergen.com
# 2982   http://www.zynerba.com
# 2983     http://www.zynex.com
#
# [2984 rows x 28 columns]

# %%
# tickers = tickers_df['ticker'].unique().tolist()
# len(tickers), len(tickers)

# %%
# with open('tmp.txt', 'w') as f:
#     f.write('"' + '", "'.join(tickers) + '"')

# %% [markdown]
# ## Tickers (batch)

# %%
def _format_quandl_url(path: str) -> str:
    config = load_config()
    return "https://www.quandl.com/api/v3/{}&api_key={}".format(path, config["quandl"]["api_key"])

# %%
path = 'datatables/SHARADAR/SF1?ticker={ticker}'
full_url = _format_quandl_url(path.format(ticker=','.join(TICKERS[:2])))

# %%
r = requests.get(full_url)
if r.status_code != 200:
    print(f'Error: {full_url}')

data = r.json()
data
# Out:
# {'datatable': {'data': [['ZI',
#     'MRY',
#     '2020-12-31',
#     '2020-12-31',
#     '2020-12-31',
#     '2021-05-03',
#     -2400000,
#     2327400000,
#     1968275000,
#     439500000,
#     1887900000,
#     0.242,
#     1.292,
#     -16800000,
#     271000000,
#     271000000,
#     107500000,
#     -36400000,
#     1.37,
#     2.76,
#     784500000,
#     6000000,
#     778500000,
#     784500000,
#     222700000,
#     50800000,
#     0,
#     0.0,
#     0.0,
#     70000000,
#     120800000,
#     0.254,
#     120800000,
#     70000000,
#     700000,
#     -0.1,
#     -0.11,
#     -0.1,
#     502800000,
#     247350000,
#     502800000,
#     19256670302,
#     275,
#     159.41,
#     152800000,
#     0.392,
#     1.0,
#     368700000,
#     0.774,
#     1365800000,
#     69300000,
#     1154300000,
#     1062425000,
#     0,
#     30600000,
#     30600000,
#     0,
#     1387800000,
#     320800000,
#     1067000000,
#     18776470302,
#     228500000,
#     -65900000,
#     691300000,
#     -476900000,
#     0,
#     172200000,
#     -113300000,
#     -30600000,
#     169600000,
#     0,
#     -4000000,
#     -4000000,
#     -4000000,
#     0,
#     -32400000,
#     -0.008,
#     331600000,
#     37100000,
#     8600000,
#     0.0,
#     37.344,
#     -4694.118,
#     -482.3,
#     63000000,
#     0,
#     48.23,
#     39.43,
#     39.43,
#     121200000,
#     -4000000,
#     476200000,
#     476200000,
#     51400000,
#     -0.002,
#     -0.016,
#     0.066,
#     0.147,
#     121600000,
#     247700000,
#     1.0,
#     389311016,
#     389311016,
#     None,
#     1.223,
#     961600000,
#     418100000,
#     4700000,
#     282700000,
#     2.47,
#     118700000],
#    ['ZI',
#     'MRY',
#     '2019-12-31',
#     '2019-12-31',
#     '2019-12-31',
#     '2021-05-03',
#     -6000000,
#     1561900000,
#     1076450000,
#     148200000,
#     1413700000,
#     0.272,
#     -0.559,
#     -13600000,
#     42500000,
#     42500000,
#     68600000,
#     -78000000,
#     0.613,
#     -7.369,
#     1248000000,
#     12700000,
#     1235300000,
#     1248000000,
#     159100000,
#     48700000,
#     0,
#     None,
#     0.0,
#     95900000,
#     144600000,
#     0.493,
#     144600000,
#     95900000,
#     -6500000,
#     None,
#     None,
#     None,
#     -213800000,
#     -166450000,
#     -213800000,
#     None,
#     None,
#     None,
#     30800000,
#     0.081,
#     1.0,
#     224700000,
#     0.766,
#     1337400000,
#     102400000,
#     1188300000,
#     902000000,
#     0,
#     0,
#     0,
#     0,
#     1575500000,
#     241700000,
#     1333800000,
#     None,
#     33500000,
#     -723100000,
#     188300000,
#     554300000,
#     0,
#     725800000,
#     -736700000,
#     0,
#     44400000,
#     0,
#     0,
#     0,
#     0,
#     0,
#     -78000000,
#     0.0,
#     188600000,
#     36100000,
#     7900000,
#     None,
#     None,
#     None,
#     None,
#     60100000,
#     0,
#     None,
#     None,
#     None,
#     86900000,
#     0,
#     293300000,
#     293300000,
#     30100000,
#     0.0,
#     0.0,
#     0.106,
#     0.327,
#     25100000,
#     125300000,
#     1.0,
#     382590936,
#     382590936,
#     None,
#     0.767,
#     224500000,
#     3900000,
#     -6500000,
#     83300000,
#     0.587,
#     -93500000],
#    ['ZI',
#     'MRY',
#     '2018-12-31',
#     '2018-12-31',
#     '2018-12-31',
#     '2021-05-03',
#     0,
#     591000000,
#     None,
#     45000000,
#     546000000,
#     None,
#     None,
#     -4600000,
#     9000000,
#     9000000,
#     37800000,
#     -28600000,
#     0.686,
#     -5.962,
#     633700000,
#     1900000,
#     631800000,
#     633700000,
#     52500000,
#     17300000,
#     0,
#     None,
#     0.0,
#     55300000,
#     72600000,
#     0.503,
#     72600000,
#     55300000,
#     -2900000,
#     None,
#     None,
#     None,
#     -119100000,
#     None,
#     -119100000,
#     None,
#     None,
#     None,
#     39200000,
#     None,
#     1.0,
#     106500000,
#     0.738,
#     534400000,
#     58200000,
#     615700000,
#     None,
#     0,
#     0,
#     0,
#     0,
#     710100000,
#     65600000,
#     644500000,
#     None,
#     800000,
#     -8500000,
#     0,
#     63500000,
#     0,
#     -29900000,
#     -13100000,
#     0,
#     43800000,
#     0,
#     0,
#     0,
#     0,
#     0,
#     -28600000,
#     0.0,
#     79900000,
#     26600000,
#     1900000,
#     None,
#     None,
#     None,
#     None,
#     9600000,
#     0,
#     None,
#     None,
#     None,
#     31200000,
#     None,
#     144300000,
#     144300000,
#     6100000,
#     None,
#     None,
#     None,
#     0.383,
#     32700000,
#     63200000,
#     1.0,
#     None,
#     None,
#     None,
#     None,
#     56600000,
#     100000,
#     -2900000,
#     10300000,
#     None,
#     -20600000],
#    ['ZI',
#     'MRT',
#     '2021-03-31',
#     '2021-03-31',
#     '2021-03-31',
#     '2021-05-03',
#     1600000,
#     2547000000,
#     2210550000,
#     485500000,
#     2061500000,
#     0.239,
#     1.419,
#     -17400000,
#     229200000,
#     229200000,
#     115200000,
#     -64400000,
#     1.394,
#     2.887,
#     778400000,
#     7100000,
#     771300000,
#     778400000,
#     261900000,
#     54100000,
#     0,
#     0.0,
#     0.0,
#     105300000,
#     159400000,
#     0.302,
#     159400000,
#     105300000,
#     54000000,
#     -0.09,
#     -0.11,
#     -0.09,
#     554300000,
#     440950000,
#     554300000,
#     19616777032,
#     186,
#     123.066,
#     216900000,
#     0.555,
#     1.0,
#     412100000,
#     0.782,
#     1354200000,
#     51300000,
#     1393800000,
#     1103225000,
#     0,
#     126600000,
#     124600000,
#     2000000,
#     1600100000,
#     348200000,
#     1251900000,
#     19103277032,
#     167100000,
#     -66100000,
#     697300000,
#     -520900000,
#     5000000,
#     141000000,
#     -208200000,
#     -124700000,
#     234300000,
#     0,
#     -800000,
#     -800000,
#     -800000,
#     0,
#     -63600000,
#     -0.002,
#     367300000,
#     44800000,
#     13800000,
#     0.0,
#     34.464,
#     -23879.096,
#     -543.333,
#     61100000,
#     0,
#     48.9,
#     36.228,
#     36.228,
#     115200000,
#     -800000,
#     527300000,
#     527300000,
#     61900000,
#     0.0,
#     -0.002,
#     0.095,
#     0.2,
#     128400000,
#     271200000,
#     1.0,
#     390660062,
#     390660062,
#     None,
#     1.35,
#     1192800000,
#     585900000,
#     54800000,
#     483700000,
#     3.053,
#     137300000],
#    ['ZI',
#     'MRT',
#     '2020-12-31',
#     '2020-12-31',
#     '2020-12-31',
#     '2021-05-03',
#     -2400000,
#     2327400000,
#     1968275000,
#     439500000,
#     1887900000,
#     0.242,
#     1.292,
#     -16800000,
#     271000000,
#     271000000,
#     107500000,
#     -36400000,
#     1.37,
#     2.76,
#     784500000,
#     6000000,
#     778500000,
#     784500000,
#     222700000,
#     50800000,
#     0,
#     0.0,
#     0.0,
#     70000000,
#     120800000,
#     0.254,
#     120800000,
#     70000000,
#     700000,
#     -0.1,
#     -0.11,
#     -0.1,
#     502800000,
#     247350000,
#     502800000,
#     19256670302,
#     275,
#     159.41,
#     152800000,
#     0.392,
#     1.0,
#     368700000,
#     0.774,
#     1365800000,
#     69300000,
#     1154300000,
#     1062425000,
#     0,
#     30600000,
#     30600000,
#     0,
#     1387800000,
#     320800000,
#     1067000000,
#     18776470302,
#     228500000,
#     -65900000,
#     691300000,
#     -476900000,
#     0,
#     172200000,
#     -113300000,
#     -30600000,
#     169600000,
#     0,
#     -4000000,
#     -4000000,
#     -4000000,
#     0,
#     -32400000,
#     -0.008,
#     331600000,
#     37100000,
#     8600000,
#     0.0,
#     37.344,
#     -4694.118,
#     -482.3,
#     63000000,
#     0,
#     48.23,
#     39.43,
#     39.43,
#     121200000,
#     -4000000,
#     476200000,
#     476200000,
#     51400000,
#     -0.002,
#     -0.016,
#     0.066,
#     0.147,
#     121600000,
#     247700000,
#     1.0,
#     389311016,
#     389311016,
#     None,
#     1.223,
#     961600000,
#     418100000,
#     4700000,
#     282700000,
#     2.47,
#     118700000],
#    ['ZI',
#     'MRT',
#     '2020-09-30',
#     '2020-09-30',
#     '2020-09-30',
#     '2021-05-03',
#     -2900000,
#     2048500000,
#     1776900000,
#     421400000,
#     1627100000,
#     0.241,
#     0.96,
#     -16100000,
#     306000000,
#     306000000,
#     99400000,
#     -78200000,
#     1.703,
#     3.287,
#     786200000,
#     4900000,
#     781300000,
#     786200000,
#     176000000,
#     49000000,
#     0,
#     0.0,
#     0.0,
#     64300000,
#     113300000,
#     0.265,
#     113300000,
#     64300000,
#     -20500000,
#     None,
#     None,
#     None,
#     373600000,
#     68200000,
#     373600000,
#     17259632609,
#     268,
#     152.336,
#     103600000,
#     0.266,
#     1.0,
#     328200000,
#     0.768,
#     1306800000,
#     84800000,
#     974400000,
#     1070925000,
#     0,
#     0,
#     0,
#     0,
#     1228000000,
#     247500000,
#     980500000,
#     16733832609,
#     265800000,
#     -8200000,
#     691300000,
#     -479100000,
#     5000000,
#     170400000,
#     -24300000,
#     0,
#     119700000,
#     0,
#     -29500000,
#     -29500000,
#     -29500000,
#     0,
#     -48700000,
#     -0.069,
#     301500000,
#     26700000,
#     9700000,
#     None,
#     44.791,
#     -567.249,
#     None,
#     62400000,
#     0,
#     42.99,
#     39.134,
#     39.134,
#     90400000,
#     -29500000,
#     427600000,
#     427600000,
#     45400000,
#     -0.017,
#     -0.433,
#     0.06,
#     0.15,
#     112200000,
#     221400000,
#     1.0,
#     389249421,
#     389249421,
#     None,
#     1.099,
#     741700000,
#     242200000,
#     9000000,
#     195600000,
#     1.905,
#     173900000],
#    ['ZI',
#     'MRT',
#     '2020-06-30',
#     '2020-06-30',
#     '2020-06-30',
#     '2021-05-03',
#     -2800000,
#     1919300000,
#     None,
#     372700000,
#     1546600000,
#     None,
#     0.871,
#     -15600000,
#     260200000,
#     260200000,
#     90500000,
#     -101700000,
#     1.568,
#     3.41,
#     786000000,
#     4000000,
#     782000000,
#     786000000,
#     172100000,
#     49500000,
#     0,
#     0.0,
#     0.0,
#     73800000,
#     123300000,
#     0.322,
#     123300000,
#     73800000,
#     -27800000,
#     None,
#     None,
#     None,
#     333100000,
#     None,
#     333100000,
#     20742015464,
#     281,
#     168.224,
#     73500000,
#     0.192,
#     1.0,
#     292800000,
#     0.764,
#     1317000000,
#     101600000,
#     890400000,
#     None,
#     0,
#     0,
#     0,
#     0,
#     1136000000,
#     237700000,
#     898300000,
#     19523615464,
#     230100000,
#     -8200000,
#     687200000,
#     -481300000,
#     5000000,
#     164800000,
#     -23800000,
#     0,
#     89100000,
#     0,
#     -34400000,
#     -34400000,
#     -34400000,
#     0,
#     -67300000,
#     -0.09,
#     271400000,
#     21400000,
#     9900000,
#     None,
#     58.612,
#     -567.547,
#     None,
#     62100000,
#     0,
#     51.03,
#     50.936,
#     50.936,
#     89400000,
#     -34400000,
#     383300000,
#     383300000,
#     42300000,
#     None,
#     None,
#     None,
#     0.193,
#     89300000,
#     191500000,
#     1.0,
#     382590936,
#     382590936,
#     None,
#     1.002,
#     602300000,
#     153700000,
# <b>limit_output extension: Maximum message size of 10000 exceeded with 193552 characters</b>

# %%
datatable_data = np.array(data['datatable']['data'])
datatable_data
# Out:
# array([['ZI', 'MRY', '2020-12-31', ..., 282700000, 2.47, 118700000],
#        ['ZI', 'MRY', '2019-12-31', ..., 83300000, 0.587, -93500000],
#        ['ZI', 'MRY', '2018-12-31', ..., 10300000, None, -20600000],
#        ...,
#        ['HALO', 'ARQ', '2016-09-30', ..., 0, 2.204, 219945000],
#        ['HALO', 'ARQ', '2016-06-30', ..., 0, 2.314, 245459000],
#        ['HALO', 'ARQ', '2016-03-31', ..., 0, 2.422, 232812000]],
#       dtype=object)

# %%
ticker_seq = np.array([x[0] for x in data['datatable']['data']])
ticker_seq
# Out:
# array(['ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI',
#        'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI',
#        'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI',
#        'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'ZI', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO', 'HALO',
#        'HALO', 'HALO', 'HALO', 'HALO'], dtype='<U4')

# %%
base_path = '/Users/kirillgugaev/Dev/finance/ML-shares-trader/datasets/quandl/quarterly'

# %%
exist_tickers = [x.split('.')[0] for x in os.listdir(base_path)]
exist_tickers
# Out:
# ['COHR',
#  'AGCO',
#  'T',
#  'AZPN',
#  'MFGP',
#  'PJT',
#  'PHM',
#  'CLDT',
#  'ADM',
#  'CRI',
#  'NUS',
#  'TNET',
#  'SLDB',
#  'BPMC',
#  'TRIP',
#  'ATRC',
#  'MSEX',
#  'SBGI',
#  'OII',
#  'APD',
#  'ANET',
#  'AFMD',
#  'SBUX',
#  'AMED',
#  'PATH',
#  'CORT',
#  'EPC',
#  'HSKA',
#  'ENDP',
#  'NJR',
#  'KEX',
#  'FTCI',
#  'UA',
#  'JKHY',
#  'ZEN',
#  'ROG',
#  'GBCI',
#  'ITW',
#  'OGS',
#  'TRHC',
#  'OKE',
#  'MRNA',
#  'QADA',
#  'IFF',
#  'BRX',
#  'PPG',
#  'IRDM',
#  'MCRI',
#  'SAIC',
#  'MMI',
#  'BEN',
#  'SWI',
#  'PKG',
#  'VCRA',
#  'CNMD',
#  'GE',
#  'SYF',
#  'SYNH',
#  'OFIX',
#  'WBA',
#  'BBBY',
#  'CBRE',
#  'LGND',
#  'WM',
#  'HOLX',
#  'WRLD',
#  'WSO',
#  'CGNX',
#  'TMX',
#  'EXLS',
#  'A',
#  'COTY',
#  'EMN',
#  'APPH',
#  'ACMR',
#  'BMY',
#  'TSCO',
#  'AXON',
#  'ACAD',
#  'CTAS',
#  'ASGN',
#  'PSX',
#  'AOUT',
#  'LMT',
#  'CTXS',
#  'SNPS',
#  'LPLA',
#  'SPOT',
#  'ASIX',
#  'BOOT',
#  'ATRO',
#  'HAE',
#  'PSA',
#  'AMP',
#  'TXN',
#  'VRTV',
#  'HST',
#  'ETN',
#  'BCO',
#  'PAGS',
#  'PRG',
#  'VAC',
#  'RS',
#  'INSP',
#  'SLP',
#  'ALV',
#  'USB',
#  'NTRS',
#  'APH',
#  'VREX',
#  'WWW',
#  'YELP',
#  'OLED',
#  'IAA',
#  'ROK',
#  'LPL',
#  'CCK',
#  'SITE',
#  'SPLK',
#  'LAZR',
#  'NTLA',
#  'NTNX',
#  'MAS',
#  'DCI',
#  'CSGP',
#  'MLAB',
#  'RF',
#  'GDRX',
#  'FIS',
#  'MDT',
#  'WAFD',
#  'HIG',
#  'ENTA',
#  'TRU',
#  'FRPT',
#  'SFIX',
#  'CAG',
#  'VMEO',
#  'XOM',
#  'FLT',
#  'PRTS',
#  'PLUS',
#  'NWS',
#  'EAT',
#  'VG',
#  'PEGA',
#  'STZ',
#  'CGNT',
#  'DRNA',
#  'WSC',
#  'M',
#  'PANW',
#  'DV',
#  'ESE',
#  'AME',
#  'PNFP',
#  'SCL',
#  'BFAM',
#  'TTM',
#  'TWTR',
#  'WDAY',
#  'UBSI',
#  'FARO',
#  'GPN',
#  'RYN',
#  'SRPT',
#  'SSD',
#  'NLOK',
#  'BAC',
#  'XEC',
#  'THS',
#  'IPAR',
#  'BILL',
#  'HQY',
#  'CENTA',
#  'NVEE',
#  'CI',
#  'AMD',
#  'RIG',
#  'FCFS',
#  'NTAP',
#  'HA',
#  'TOL',
#  'L',
#  'WELL',
#  'AFL',
#  'ECL',
#  'CMP',
#  'SKLZ',
#  'OTIS',
#  'LPX',
#  'SYK',
#  'GH',
#  'COUR',
#  'OMCL',
#  'MDU',
#  'MLHR',
#  'AES',
#  'MGRC',
#  'GTN',
#  'SRC',
#  'CFX',
#  'ARE',
#  'DDOG',
#  'MCK',
#  'MAR',
#  'FUL',
#  'ZBH',
#  'ALB',
#  'HUM',
#  'ED',
#  'JCI',
#  'PEP',
#  'CME',
#  'IR',
#  'AYX',
#  'MTH',
#  'WU',
#  'TPX',
#  'HCCI',
#  'MDLA',
#  'VIPS',
#  'RBLX',
#  'DISH',
#  'SSNC',
#  'SMTC',
#  'INCY',
#  'FOXA',
#  'GTHX',
#  'ECHO',
#  'NXST',
#  'PLAN',
#  'MOH',
#  'MLCO',
#  'SHEN',
#  'HLT',
#  'CENT',
#  'ARNC',
#  'KMB',
#  'BOX',
#  'MS',
#  'THG',
#  'GDOT',
#  'BRK',
#  'SON',
#  'RAVN',
#  'ATEX',
#  'Y',
#  'BHF',
#  'RRGB',
#  'BURL',
#  'DIS',
#  'SJI',
#  'VEC',
#  'USFD',
#  'ELAN',
#  'ALGT',
#  'CACC',
#  'FTNT',
#  'DOCS',
#  'JCOM',
#  'PLUG',
#  'ALLE',
#  'ZUMZ',
#  'IEX',
#  'GPC',
#  'ZYNE',
#  'LOPE',
#  'ATNI',
#  'CE',
#  'ASO',
#  'PUMP',
#  'KTB',
#  'XRX',
#  'SHI',
#  'DKS',
#  'HFC',
#  'RBC',
#  'SUPN',
#  'IRBT',
#  'TCRR',
#  'NRIX',
#  'CNC',
#  'FB',
#  'LDOS',
#  'CBU',
#  'NEO',
#  'MKSI',
#  'MHO',
#  'KR',
#  'MXIM',
#  'HWM',
#  'GD',
#  'CHRW',
#  'LYFT',
#  'CRSP',
#  'BC',
#  'APP',
#  'INTC',
#  'SHLS',
#  'FTCH',
#  'HEI',
#  'EBS',
#  'WY',
#  'UFPI',
#  'LCII',
#  'CMCO',
#  'CARA',
#  'BKU',
#  'NFE',
#  'COP',
#  'MTD',
#  'SNAP',
#  'HLNE',
#  'CMI',
#  'KEY',
#  'PG',
#  'ABT',
#  'AJRD',
#  'LEN',
#  'BZUN',
#  'NWLI',
#  'BLK',
#  'KRYS',
#  'IVZ',
#  'DLX',
#  'NCBS',
#  'HUBB',
#  'MBT',
#  'HOG',
#  'PCAR',
#  'SAM',
#  'MELI',
#  'URI',
#  'YEXT',
#  'HSY',
#  'RRBI',
#  'POR',
#  'PTR',
#  'FOLD',
#  'ZI',
#  'PXD',
#  'ILMN',
#  'VNDA',
#  'FISV',
#  'XP',
#  'CRWD',
#  'SXT',
#  'DCPH',
#  'TRNO',
#  'U',
#  'LANC',
#  'JLL',
#  'SHW',
#  'TM',
#  'MNST',
#  'LAD',
#  'VIR',
#  'VRSN',
#  'HHR',
#  'POWI',
#  'DE',
#  'MRTX',
#  'FOX',
#  'MCHP',
#  'FCN',
#  'VZIO',
#  'ATRI',
#  'NRG',
#  'DLTR',
#  'EEFT',
#  'ARCT',
#  'DASH',
#  'CLOV',
#  'KALU',
#  'BJRI',
#  'PFPT',
#  'YETI',
#  'BERY',
#  'APTV',
#  'CHKP',
#  'ARW',
#  'POSH',
#  'PBI',
#  'FOXF',
#  'CHE',
#  'TDOC',
#  'PINC',
#  'DHR',
#  'CALM',
#  'WING',
#  'BIG',
#  'SYY',
#  'XLNX',
#  'CAT',
#  'UDR',
#  'ALE',
#  'USNA',
#  'HBI',
#  'MMC',
#  'INMD',
#  'PLCE',
#  'WWD',
#  'RXN',
#  'WLTW',
#  'MTCH',
#  'RTX',
#  'SYKE',
#  'BH',
#  'TNDM',
#  'FOCS',
#  'ENTG',
#  'NVS',
#  'BOKF',
#  'CPRI',
#  'GO',
#  'FLR',
#  'MXL',
#  'IDXX',
#  'TROW',
#  'DIOD',
#  'MET',
#  'WAT',
#  'SFM',
#  'CIEN',
#  'IBM',
#  'MGM',
#  'WMB',
#  'TMUS',
#  'EAR',
#  'ARVN',
#  'K',
#  'CASY',
#  'WABC',
#  'NATI',
#  'SF',
#  'CINF',
#  'NPK',
#  'CTSH',
#  'BLMN',
#  'PNTG',
#  'MA',
#  'TDC',
#  'GGG',
#  'DECK',
#  'R',
#  'STE',
#  'APLE',
#  'LFUS',
#  'GWRE',
#  'IIPR',
#  'CLH',
#  'NWL',
#  'LUMN',
#  'CLDR',
#  'QNST',
#  'SEDG',
#  'LITE',
#  'AEIS',
#  'RNG',
#  'VPG',
#  'AN',
#  'OHI',
#  'KMI',
#  'TFC',
#  'NMIH',
#  'CW',
#  'UNP',
#  'EXR',
#  'FLWS',
#  'NAVI',
#  'AAL',
#  'ORLY',
#  'COST',
#  'BLL',
#  'RDFN',
#  'ITGR',
#  'VLDR',
#  'SPGI',
#  'NFLX',
#  'NBIX',
#  'CORR',
#  'STRA',
#  'RJF',
#  'BKR',
#  'TWNK',
#  'GILD',
#  'GSHD',
#  'LTHM',
#  'KMPR',
#  'SONO',
#  'MTOR',
#  'UAL',
#  'LYB',
#  'IRTC',
#  'MSFT',
#  'AMGN',
#  'MOV',
#  'RL',
#  'CHEF',
#  'MDRX',
#  'IQV',
#  'AWI',
#  'SCHW',
#  'DXC',
#  'IONS',
#  'TRMB',
#  'CARS',
#  'PEN',
#  'SLGN',
#  'CCXI',
#  'AIN',
#  'LNT',
#  'FBHS',
#  'VIRT',
#  'INVH',
#  'SMAR',
#  'WK',
#  'DISCB',
#  'LEVI',
#  'HIBB',
#  'FELE',
#  'ZTS',
#  'RAMP',
#  'VIAC',
#  'FWRD',
#  'SJW',
#  'TT',
#  'AFG',
#  'APPN',
#  'BXP',
#  'ICPT',
#  'CWST',
#  'ASH',
#  'EVH',
#  'BECN',
#  'CB',
#  'MBUU',
#  'BSX',
#  'LFC',
#  'ROCK',
#  'QS',
#  'MORN',
#  'VNT',
#  'AMN',
#  'SAFM',
#  'MSGS',
#  'JOUT',
#  'SAVE',
#  'MRO',
#  'BAH',
#  'PGTI',
#  'EVRG',
#  'KOD',
#  'GBT',
#  'CC',
#  'CPB',
#  'RGLD',
#  'GNTX',
#  'AMSF',
#  'BLDR',
#  'F',
#  'SBAC',
#  'PDCO',
#  'ENV',
#  'SEIC',
#  'ITRI',
#  'VFC',
#  'SWN',
#  'MGLN',
#  'UFS',
#  'WKHS',
#  'VTR',
#  'AWH',
#  'NTUS',
#  'FNF',
#  'SIVB',
#  'UBER',
#  'CARR',
#  'WEX',
#  'ABG',
#  'NVTA',
#  'SQSP',
#  'TSLA',
#  'ANIP',
#  'MSI',
#  'SRI',
#  'HRL',
#  'CFR',
#  'CDK',
#  'MOMO',
#  'TPR',
#  'HGV',
#  'NARI',
#  'CABO',
#  'TPIC',
#  'SBRA',
#  'AIZ',
#  'LLY',
#  'RARE',
#  'WBS',
#  'MASI',
#  'CARG',
#  'ABMD',
#  'MTB',
#  'LGIH',
#  'SCSC',
#  'CFG',
#  'CHH',
#  'TKR',
#  'LYV',
#  'CVET',
#  'LHX',
#  'SLAB',
#  'VEEV',
#  'MPC',
#  'TSM',
#  'MKC',
#  'EDIT',
#  'CSCO',
#  'WAL',
#  'TCBI',
#  'AAPL',
#  'MRVL',
#  'INGR',
#  'CEVA',
#  'S',
#  'HTA',
#  'PFE',
#  'CNP',
#  'GTLS',
#  'MMSI',
#  'MRC',
#  'TREX',
#  'GLW',
#  'UNH',
#  'GBX',
#  'CEA',
#  'PLNT',
#  'IOVA',
#  'FIVN',
#  'TRUP',
#  'ALLO',
#  'OVV',
#  'GPI',
#  'OXY',
#  'ACM',
#  'TGNA',
#  'NTCO',
#  'WHD',
#  'JNJ',
#  'TWOU',
#  'KFY',
#  'BDC',
#  'AVB',
#  'ABNB',
#  'GEF',
#  'J',
#  'NEE',
#  'EME',
#  'CBSH',
#  'MANH',
#  'ETSY',
#  'GWW',
#  'ADS',
#  'JPM',
#  'DVA',
#  'COO',
#  'WRB',
#  'TNL',
#  'FLS',
#  'RSG',
#  'EW',
#  'PETQ',
#  'PLTR',
#  'NVR',
#  'PWR',
#  'BKNG',
#  'SRE',
#  'UAA',
#  'WWE',
#  'NOK',
#  'BF',
#  'ICFI',
#  'IART',
#  'NTRA',
#  'COLM',
#  'ALSN',
#  'TTEK',
#  'MAT',
#  'UCTT',
#  'MVIS',
#  'SLB',
#  'PPL',
#  'PRU',
#  'CCL',
#  'HCSG',
#  'NDAQ',
#  'MTN',
#  'BLKB',
#  'CMC',
#  'IT',
#  'GHC',
#  'ATVI',
#  'BLUE',
#  'FATE',
#  'BWA',
#  'AIV',
#  'ROL',
#  'PBH',
#  'GEVO',
#  'YUMC',
#  'PEAK',
#  'CHD',
#  'TTWO',
#  'IGMS',
#  'ISRG',
#  'PM',
#  'CHGG',
#  'BBIO',
#  'MAA',
#  'IDA',
#  'CGEN',
#  'LVS',
#  'ZBRA',
#  'AMZN',
#  'RXRX',
#  'TJX',
#  'MU',
#  'MPWR',
#  'EFX',
#  'DLR',
#  'SR',
#  'AON',
#  'FITB',
#  'DD',
#  'TXRH',
#  'OMC',
#  'RPM',
#  'KHC',
#  'TAP',
#  'VUZI',
#  'SPCE',
#  'BBSI',
#  'ZION',
#  'ICLR',
#  'PFGC',
#  'TTMI',
#  'WORK',
#  'PRTA',
#  'RDS',
#  'MGY',
#  'TTCF',
#  'DOCU',
#  'BILI',
#  'TFX',
#  'AVTR',
#  'BOH',
#  'CL',
#  'SGEN',
#  'DPZ',
#  'PRAX',
#  'SMG',
#  'CHDN',
#  'ARCC',
#  'CVGW',
#  'ACN',
#  'KSU',
#  'HTHT',
#  'WISH',
#  'AVA',
#  'WERN',
#  'BRKR',
#  'GIS',
#  'HD',
#  'QUOT',
#  'WDFC',
#  'VC',
#  'SHOP',
#  'ADP',
#  'EXPE',
#  'QTWO',
#  'ET',
#  'UHS',
#  'BKI',
#  'GM',
#  'BABA',
#  'DORM',
#  'MTX',
#  'FLOW',
#  'RCL',
#  'TPH',
#  'FGEN',
#  'AVNT',
#  'COWN',
#  'SWKS',
#  'DDS',
#  'HRC',
#  'BJ',
#  'CHWY',
#  'ESPR',
#  'SNX',
#  'ONTO',
#  'QDEL',
#  'ROLL',
#  'CNXC',
#  'ALG',
#  'KEP',
#  'DELL',
#  'VRNT',
#  'INDB',
#  'COKE',
#  'AWR',
#  'EA',
#  'ZYXI',
#  'SEE',
#  'KLAC',
#  'ZIP',
#  'LASR',
#  'UI',
#  'CSWI',
#  'PLD',
#  'OGN',
#  'KNX',
#  'TER',
#  'MATX',
#  'VCYT',
#  'NGVT',
#  'MDGL',
#  'TYL',
#  'LEG',
#  'NSC',
#  'EPAY',
#  'LRCX',
#  'AMT',
#  'HON',
#  'NWSA',
#  'AXSM',
#  'ALLY',
#  'SQ',
#  'XYL',
#  'SDGR',
#  'WHR',
#  'UMBF',
#  'JELD',
#  'QRVO',
#  'CLF',
#  'ATKR',
#  'FMC',
#  'DG',
#  'AVT',
#  'GDDY',
#  'IOSP',
#  'MKL',
#  'SWCH',
#  'REX',
#  'ENPH',
#  'HCA',
#  'TTE',
#  'RGA',
#  'ALNY',
#  'WYNN',
#  'STAA',
#  'FRHC',
#  'MO',
#  'EVER',
#  'CTVA',
#  'CREE',
#  'ZY',
#  'AMAT',
#  'NYT',
#  'WCC',
#  'TCS',
#  'BIIB',
#  'EQT',
#  'NKE',
#  'SOHU',
#  'MUR',
#  'DHI',
#  'ICE',
#  'IBKR',
#  'VEON',
#  'AWK',
#  'GRPH',
#  'EGHT',
#  'DVN',
#  'BGS',
#  'TNC',
#  'ACIW',
#  'DOW',
#  'PPC',
#  'MMM',
#  'GNRC',
#  'LKQ',
#  'ALK',
#  'NCR',
#  'LUV',
#  'USPH',
#  'AMWD',
#  'LI',
#  'NP',
#  'AAON',
#  'DFS',
#  'PGNY',
#  'CVCO',
#  'AEO',
#  'XRAY',
#  'SWX',
#  'REGN',
#  'GT',
#  'MAN',
#  'QTS',
#  'IDCC',
#  'XNCR',
#  'FAST',
#  'SNA',
#  'PB',
#  'MSTR',
#  'ANGI',
#  'STLD',
#  'HUBG',
#  'MSGE',
#  'FTV',
#  'GPS',
#  'BNGO',
#  'AAN',
#  'EXP',
#  'PRAA',
#  'OC',
#  'KEYS',
#  'ROST',
#  'TRIT',
#  'OSK',
#  'AMCX',
#  'ADI',
#  'VZ',
#  'CRM',
#  'TSN',
#  'NVRO',
#  'GSKY',
#  'TPTX',
#  'JD',
#  'IPG',
#  'CNS',
#  'DK',
#  'AZO',
#  'BDX',
#  'PCTY',
#  'PFG',
#  'AVY',
#  'ZM',
#  'SPSC',
#  'EOG',
#  'AJG',
#  'CRL',
#  'THO',
#  'HURN',
#  'TDY',
#  'FSLR',
#  'PAY',
#  'BMI',
#  'FCNCA',
#  'QCOM',
#  'TXG',
#  'HAL',
#  'NTCT',
#  'CCOI',
#  'BLNK',
#  'SPG',
#  'IIVI',
#  'SONY',
#  'CCMP',
#  'KNBE',
#  'PBF',
#  'VSAT',
#  'BR',
#  'APA',
#  'ANF',
#  'DAL',
#  'FTDR',
#  'CVM',
#  'EGP',
#  'EXAS',
#  'ARWR',
#  'KKR',
#  'VXRT',
#  'EL',
#  'UNVR',
#  'NDSN',
#  'FRPH',
#  'GCP',
#  'OSUR',
#  'LH',
#  'SPR',
#  'DOV',
#  'CVX',
#  'LSTR',
#  'HNP',
#  'OLLI',
#  'RHI',
#  ...]

# %%
tickers_to_download = list(set(TICKERS).difference(set(exist_tickers)))
tickers_to_download
# Out:
# ['BF.B', 'BRK.B', 'RDS.A']

# %%
ticker_data = copy.deepcopy(data)
ticker = TICKERS[0]
ticker_data['datatable']['data'] = datatable_data[ticker_seq == ticker].tolist() if len(ticker_seq) else []
ticker_data
# Out:
# {'datatable': {'data': [['ZI',
#     'MRY',
#     '2020-12-31',
#     '2020-12-31',
#     '2020-12-31',
#     '2021-05-03',
#     -2400000,
#     2327400000,
#     1968275000,
#     439500000,
#     1887900000,
#     0.242,
#     1.292,
#     -16800000,
#     271000000,
#     271000000,
#     107500000,
#     -36400000,
#     1.37,
#     2.76,
#     784500000,
#     6000000,
#     778500000,
#     784500000,
#     222700000,
#     50800000,
#     0,
#     0.0,
#     0.0,
#     70000000,
#     120800000,
#     0.254,
#     120800000,
#     70000000,
#     700000,
#     -0.1,
#     -0.11,
#     -0.1,
#     502800000,
#     247350000,
#     502800000,
#     19256670302,
#     275,
#     159.41,
#     152800000,
#     0.392,
#     1.0,
#     368700000,
#     0.774,
#     1365800000,
#     69300000,
#     1154300000,
#     1062425000,
#     0,
#     30600000,
#     30600000,
#     0,
#     1387800000,
#     320800000,
#     1067000000,
#     18776470302,
#     228500000,
#     -65900000,
#     691300000,
#     -476900000,
#     0,
#     172200000,
#     -113300000,
#     -30600000,
#     169600000,
#     0,
#     -4000000,
#     -4000000,
#     -4000000,
#     0,
#     -32400000,
#     -0.008,
#     331600000,
#     37100000,
#     8600000,
#     0.0,
#     37.344,
#     -4694.118,
#     -482.3,
#     63000000,
#     0,
#     48.23,
#     39.43,
#     39.43,
#     121200000,
#     -4000000,
#     476200000,
#     476200000,
#     51400000,
#     -0.002,
#     -0.016,
#     0.066,
#     0.147,
#     121600000,
#     247700000,
#     1.0,
#     389311016,
#     389311016,
#     None,
#     1.223,
#     961600000,
#     418100000,
#     4700000,
#     282700000,
#     2.47,
#     118700000],
#    ['ZI',
#     'MRY',
#     '2019-12-31',
#     '2019-12-31',
#     '2019-12-31',
#     '2021-05-03',
#     -6000000,
#     1561900000,
#     1076450000,
#     148200000,
#     1413700000,
#     0.272,
#     -0.559,
#     -13600000,
#     42500000,
#     42500000,
#     68600000,
#     -78000000,
#     0.613,
#     -7.369,
#     1248000000,
#     12700000,
#     1235300000,
#     1248000000,
#     159100000,
#     48700000,
#     0,
#     None,
#     0.0,
#     95900000,
#     144600000,
#     0.493,
#     144600000,
#     95900000,
#     -6500000,
#     None,
#     None,
#     None,
#     -213800000,
#     -166450000,
#     -213800000,
#     None,
#     None,
#     None,
#     30800000,
#     0.081,
#     1.0,
#     224700000,
#     0.766,
#     1337400000,
#     102400000,
#     1188300000,
#     902000000,
#     0,
#     0,
#     0,
#     0,
#     1575500000,
#     241700000,
#     1333800000,
#     None,
#     33500000,
#     -723100000,
#     188300000,
#     554300000,
#     0,
#     725800000,
#     -736700000,
#     0,
#     44400000,
#     0,
#     0,
#     0,
#     0,
#     0,
#     -78000000,
#     0.0,
#     188600000,
#     36100000,
#     7900000,
#     None,
#     None,
#     None,
#     None,
#     60100000,
#     0,
#     None,
#     None,
#     None,
#     86900000,
#     0,
#     293300000,
#     293300000,
#     30100000,
#     0.0,
#     0.0,
#     0.106,
#     0.327,
#     25100000,
#     125300000,
#     1.0,
#     382590936,
#     382590936,
#     None,
#     0.767,
#     224500000,
#     3900000,
#     -6500000,
#     83300000,
#     0.587,
#     -93500000],
#    ['ZI',
#     'MRY',
#     '2018-12-31',
#     '2018-12-31',
#     '2018-12-31',
#     '2021-05-03',
#     0,
#     591000000,
#     None,
#     45000000,
#     546000000,
#     None,
#     None,
#     -4600000,
#     9000000,
#     9000000,
#     37800000,
#     -28600000,
#     0.686,
#     -5.962,
#     633700000,
#     1900000,
#     631800000,
#     633700000,
#     52500000,
#     17300000,
#     0,
#     None,
#     0.0,
#     55300000,
#     72600000,
#     0.503,
#     72600000,
#     55300000,
#     -2900000,
#     None,
#     None,
#     None,
#     -119100000,
#     None,
#     -119100000,
#     None,
#     None,
#     None,
#     39200000,
#     None,
#     1.0,
#     106500000,
#     0.738,
#     534400000,
#     58200000,
#     615700000,
#     None,
#     0,
#     0,
#     0,
#     0,
#     710100000,
#     65600000,
#     644500000,
#     None,
#     800000,
#     -8500000,
#     0,
#     63500000,
#     0,
#     -29900000,
#     -13100000,
#     0,
#     43800000,
#     0,
#     0,
#     0,
#     0,
#     0,
#     -28600000,
#     0.0,
#     79900000,
#     26600000,
#     1900000,
#     None,
#     None,
#     None,
#     None,
#     9600000,
#     0,
#     None,
#     None,
#     None,
#     31200000,
#     None,
#     144300000,
#     144300000,
#     6100000,
#     None,
#     None,
#     None,
#     0.383,
#     32700000,
#     63200000,
#     1.0,
#     None,
#     None,
#     None,
#     None,
#     56600000,
#     100000,
#     -2900000,
#     10300000,
#     None,
#     -20600000],
#    ['ZI',
#     'MRT',
#     '2021-03-31',
#     '2021-03-31',
#     '2021-03-31',
#     '2021-05-03',
#     1600000,
#     2547000000,
#     2210550000,
#     485500000,
#     2061500000,
#     0.239,
#     1.419,
#     -17400000,
#     229200000,
#     229200000,
#     115200000,
#     -64400000,
#     1.394,
#     2.887,
#     778400000,
#     7100000,
#     771300000,
#     778400000,
#     261900000,
#     54100000,
#     0,
#     0.0,
#     0.0,
#     105300000,
#     159400000,
#     0.302,
#     159400000,
#     105300000,
#     54000000,
#     -0.09,
#     -0.11,
#     -0.09,
#     554300000,
#     440950000,
#     554300000,
#     19616777032,
#     186,
#     123.066,
#     216900000,
#     0.555,
#     1.0,
#     412100000,
#     0.782,
#     1354200000,
#     51300000,
#     1393800000,
#     1103225000,
#     0,
#     126600000,
#     124600000,
#     2000000,
#     1600100000,
#     348200000,
#     1251900000,
#     19103277032,
#     167100000,
#     -66100000,
#     697300000,
#     -520900000,
#     5000000,
#     141000000,
#     -208200000,
#     -124700000,
#     234300000,
#     0,
#     -800000,
#     -800000,
#     -800000,
#     0,
#     -63600000,
#     -0.002,
#     367300000,
#     44800000,
#     13800000,
#     0.0,
#     34.464,
#     -23879.096,
#     -543.333,
#     61100000,
#     0,
#     48.9,
#     36.228,
#     36.228,
#     115200000,
#     -800000,
#     527300000,
#     527300000,
#     61900000,
#     0.0,
#     -0.002,
#     0.095,
#     0.2,
#     128400000,
#     271200000,
#     1.0,
#     390660062,
#     390660062,
#     None,
#     1.35,
#     1192800000,
#     585900000,
#     54800000,
#     483700000,
#     3.053,
#     137300000],
#    ['ZI',
#     'MRT',
#     '2020-12-31',
#     '2020-12-31',
#     '2020-12-31',
#     '2021-05-03',
#     -2400000,
#     2327400000,
#     1968275000,
#     439500000,
#     1887900000,
#     0.242,
#     1.292,
#     -16800000,
#     271000000,
#     271000000,
#     107500000,
#     -36400000,
#     1.37,
#     2.76,
#     784500000,
#     6000000,
#     778500000,
#     784500000,
#     222700000,
#     50800000,
#     0,
#     0.0,
#     0.0,
#     70000000,
#     120800000,
#     0.254,
#     120800000,
#     70000000,
#     700000,
#     -0.1,
#     -0.11,
#     -0.1,
#     502800000,
#     247350000,
#     502800000,
#     19256670302,
#     275,
#     159.41,
#     152800000,
#     0.392,
#     1.0,
#     368700000,
#     0.774,
#     1365800000,
#     69300000,
#     1154300000,
#     1062425000,
#     0,
#     30600000,
#     30600000,
#     0,
#     1387800000,
#     320800000,
#     1067000000,
#     18776470302,
#     228500000,
#     -65900000,
#     691300000,
#     -476900000,
#     0,
#     172200000,
#     -113300000,
#     -30600000,
#     169600000,
#     0,
#     -4000000,
#     -4000000,
#     -4000000,
#     0,
#     -32400000,
#     -0.008,
#     331600000,
#     37100000,
#     8600000,
#     0.0,
#     37.344,
#     -4694.118,
#     -482.3,
#     63000000,
#     0,
#     48.23,
#     39.43,
#     39.43,
#     121200000,
#     -4000000,
#     476200000,
#     476200000,
#     51400000,
#     -0.002,
#     -0.016,
#     0.066,
#     0.147,
#     121600000,
#     247700000,
#     1.0,
#     389311016,
#     389311016,
#     None,
#     1.223,
#     961600000,
#     418100000,
#     4700000,
#     282700000,
#     2.47,
#     118700000],
#    ['ZI',
#     'MRT',
#     '2020-09-30',
#     '2020-09-30',
#     '2020-09-30',
#     '2021-05-03',
#     -2900000,
#     2048500000,
#     1776900000,
#     421400000,
#     1627100000,
#     0.241,
#     0.96,
#     -16100000,
#     306000000,
#     306000000,
#     99400000,
#     -78200000,
#     1.703,
#     3.287,
#     786200000,
#     4900000,
#     781300000,
#     786200000,
#     176000000,
#     49000000,
#     0,
#     0.0,
#     0.0,
#     64300000,
#     113300000,
#     0.265,
#     113300000,
#     64300000,
#     -20500000,
#     None,
#     None,
#     None,
#     373600000,
#     68200000,
#     373600000,
#     17259632609,
#     268,
#     152.336,
#     103600000,
#     0.266,
#     1.0,
#     328200000,
#     0.768,
#     1306800000,
#     84800000,
#     974400000,
#     1070925000,
#     0,
#     0,
#     0,
#     0,
#     1228000000,
#     247500000,
#     980500000,
#     16733832609,
#     265800000,
#     -8200000,
#     691300000,
#     -479100000,
#     5000000,
#     170400000,
#     -24300000,
#     0,
#     119700000,
#     0,
#     -29500000,
#     -29500000,
#     -29500000,
#     0,
#     -48700000,
#     -0.069,
#     301500000,
#     26700000,
#     9700000,
#     None,
#     44.791,
#     -567.249,
#     None,
#     62400000,
#     0,
#     42.99,
#     39.134,
#     39.134,
#     90400000,
#     -29500000,
#     427600000,
#     427600000,
#     45400000,
#     -0.017,
#     -0.433,
#     0.06,
#     0.15,
#     112200000,
#     221400000,
#     1.0,
#     389249421,
#     389249421,
#     None,
#     1.099,
#     741700000,
#     242200000,
#     9000000,
#     195600000,
#     1.905,
#     173900000],
#    ['ZI',
#     'MRT',
#     '2020-06-30',
#     '2020-06-30',
#     '2020-06-30',
#     '2021-05-03',
#     -2800000,
#     1919300000,
#     None,
#     372700000,
#     1546600000,
#     None,
#     0.871,
#     -15600000,
#     260200000,
#     260200000,
#     90500000,
#     -101700000,
#     1.568,
#     3.41,
#     786000000,
#     4000000,
#     782000000,
#     786000000,
#     172100000,
#     49500000,
#     0,
#     0.0,
#     0.0,
#     73800000,
#     123300000,
#     0.322,
#     123300000,
#     73800000,
#     -27800000,
#     None,
#     None,
#     None,
#     333100000,
#     None,
#     333100000,
#     20742015464,
#     281,
#     168.224,
#     73500000,
#     0.192,
#     1.0,
#     292800000,
#     0.764,
#     1317000000,
#     101600000,
#     890400000,
#     None,
#     0,
#     0,
#     0,
#     0,
#     1136000000,
#     237700000,
#     898300000,
#     19523615464,
#     230100000,
#     -8200000,
#     687200000,
#     -481300000,
#     5000000,
#     164800000,
#     -23800000,
#     0,
#     89100000,
#     0,
#     -34400000,
#     -34400000,
#     -34400000,
#     0,
#     -67300000,
#     -0.09,
#     271400000,
#     21400000,
#     9900000,
#     None,
#     58.612,
#     -567.547,
#     None,
#     62100000,
#     0,
#     51.03,
#     50.936,
#     50.936,
#     89400000,
#     -34400000,
#     383300000,
#     383300000,
#     42300000,
#     None,
#     None,
#     None,
#     0.193,
#     89300000,
#     191500000,
#     1.0,
#     382590936,
#     382590936,
#     None,
#     1.002,
#     602300000,
#     153700000,
# <b>limit_output extension: Maximum message size of 10000 exceeded with 60711 characters</b>
